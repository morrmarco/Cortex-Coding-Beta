# %% [markdown]
# # 1. Check your Python Version

# %%
from platform import python_version
print (python_version())
# Out:
# 3.8.8

# %% [markdown]
# # 2. Install SASPy

# %%
pip install saspy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 3. Check the file path for configuration file "sascfg_personal.py"

# %%
import saspy, os
print(saspy.__file__.replace('__init__.py', 'sascfg_personal.py'))
# Out:
# C:\Users\hzhou\anaconda3\lib\site-packages\saspy\sascfg_personal.py

# %% [markdown]
# # 4. Establish Connection (Need to do it everytime when you use SASPy)

# %%
import saspy
sas_session = saspy.SASsession()
sas_session
# Out:
# Using SAS Config named: oda
# SAS Connection established. Subprocess id is 90276
# Access Method         = IOM
# SAS Config name       = oda
# SAS Config file       = C:\Users\hzhou\anaconda3\lib\site-packages\saspy\sascfg_personal.py
# WORK Path             = /saswork/SAS_workA2650000B0B3_odaws03-usw2.oda.sas.com/SAS_work487C0000B0B3_odaws03-usw2.oda.sas.com/
# SAS Version           = 9.04.01M6P11072018
# SASPy Version         = 3.7.2
# Teach me SAS          = False
# Batch                 = False
# Results               = Pandas
# SAS Session Encoding  = utf-8
# Python Encoding value = utf-8
# SAS process Pid value = 45235

# %% [markdown]
# # 5. Access Cortex Dataset in SAS Studio

# %%
# %%SAS sas_session
#
# libname cortex '/home/u58555463/my_shared_file_links/u39842936/Cortex Data Sets';
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2021 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# ...
